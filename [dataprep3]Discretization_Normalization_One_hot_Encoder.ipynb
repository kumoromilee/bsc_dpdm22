# %% [markdown]
# <a href="https://colab.research.google.com/github/kumoromilee/bsc_dpdm22/blob/main/%5Bdataprep3%5DDiscretization_Normalization_One_hot_Encoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Normalization-Standardzation
# https://scikit-learn.org/stable/modules/preprocessing.html?fbclid=IwAR0lDI-xJkIQ2HrJ_G1Q5ngrlCdU1XQHngBqg-EPveyaqOYj2LOlOonz-Is

# %%
import pandas as pd

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
weather_data = pd.read_csv('//content/drive/MyDrive/bsc_DPDM_data/Group2_12สุจีรา_14จิราพัชร_15กัลยรัตน์_23ชุติมา.csv')

# %%
weather_data.shape
# Out:
# (5345, 13)

# %%
weather_data
# Out:
#       จังหวัด                     สถานี  เดือน    ปี  วันที่   ความกด  \
# 0     ขอนแก่น  352201-หนองคาย จ.หนองคาย     10  2011       1  1005.47
# 1     ขอนแก่น  352201-หนองคาย จ.หนองคาย     10  2011       2  1006.65
# 2     ขอนแก่น  352201-หนองคาย จ.หนองคาย     10  2011       3  1007.49
# 3     ขอนแก่น  352201-หนองคาย จ.หนองคาย     10  2011       4  1008.28
# 4     ขอนแก่น  352201-หนองคาย จ.หนองคาย     10  2011       5  1009.88
# ...       ...                       ...    ...   ...     ...      ...
# 5340      เลย  352201-หนองคาย จ.หนองคาย      2  2022      23  1017.65
# 5341      เลย  352201-หนองคาย จ.หนองคาย      2  2022      25  1017.80
# 5342      เลย  352201-หนองคาย จ.หนองคาย      2  2022      26  1016.54
# 5343      เลย  352201-หนองคาย จ.หนองคาย      2  2022      27  1014.97
# 5344      เลย  352201-หนองคาย จ.หนองคาย      2  2022      28  1012.88
#
#       ความชื้น  อุณหภูมิตุ้มแห้ง  อุณหภูมิจุดน้ำค้าง  อุณหภูมิต่ำสุด  \
# ...

# %%
data_features = weather_data.iloc[:,5:]
data_features.head()
# Out:
#     ความกด  ความชื้น  อุณหภูมิตุ้มแห้ง  อุณหภูมิจุดน้ำค้าง  อุณหภูมิต่ำสุด  \
# 0  1005.47      83.0              27.6                24.2            24.8
# 1  1006.65      92.0              25.6                24.0            23.0
# 2  1007.49      86.0              25.6                22.9            22.1
# 3  1008.28      80.0              25.8                21.9            22.8
# 4  1009.88      86.0              24.3                21.7            23.1
#
#    จำนวนเมฆ ปริมาณฝน  ความเร็วลม
# 0         9      1.4           3
# 1        10     17.7           2
# 2        10        3           3
# 3         8        0           2
# 4        10      2.2           2

# %%
data_features.dtypes
# Out:
# ความกด                float64
# ความชื้น              float64
# อุณหภูมิตุ้มแห้ง      float64
# อุณหภูมิจุดน้ำค้าง    float64
# อุณหภูมิต่ำสุด        float64
# จำนวนเมฆ                int64
# ปริมาณฝน               object
# ความเร็วลม              int64
# dtype: object

# %%
data_features.describe()
# Out:
#             ความกด     ความชื้น  อุณหภูมิตุ้มแห้ง  อุณหภูมิจุดน้ำค้าง  \
# count  5198.000000  5198.000000       5061.000000         5061.000000
# mean   1012.722753   318.164052         25.002667           18.420944
# std       3.167502   413.573766          2.720534            3.630472
# min    1002.040000    43.000000         11.800000            1.500000
# 25%    1010.760000    68.000000         23.500000           16.100000
# 50%    1012.620000    77.000000         25.400000           18.500000
# 75%    1014.710000  1008.005000         26.900000           21.200000
# max    1026.100000  1025.710000         31.000000           28.400000
#
#        อุณหภูมิต่ำสุด     จำนวนเมฆ   ความเร็วลม
# count     5198.000000  5198.000000  5198.000000
# mean        19.904482     3.312620     2.260100
# std          3.302005     2.503989     1.206769
# min          6.800000     0.000000     0.000000
# 25%         17.800000     1.000000     1.000000
# ...

# %%
#data_features['ปริมาณฝน'] = data_features['ปริมาณฝน'].astype(int) #เปลี่ยนทีละบรรทัด

# %%
#x[x.eq('-').any(1)]#หาแถวที่มีค่าที่เราต้องการ

# %%
data_features[data_features.eq("ปริมาณฝน").any(1)]
# Out:
# Empty DataFrame
# Columns: [ความกด, ความชื้น, อุณหภูมิตุ้มแห้ง, อุณหภูมิจุดน้ำค้าง, อุณหภูมิต่ำสุด, จำนวนเมฆ, ปริมาณฝน, ความเร็วลม]
# Index: []

# %%
data_features[data_features.eq("ปริมาณฝน").any(1)] #หาแถวที่มีค่าที่เราต้องการ
# Out:
# Empty DataFrame
# Columns: [ความกด, ความชื้น, อุณหภูมิตุ้มแห้ง, อุณหภูมิจุดน้ำค้าง, อุณหภูมิต่ำสุด, จำนวนเมฆ, ปริมาณฝน, ความเร็วลม]
# Index: []

# %%
#weather_data[weather_data("ปริมาณฝน").eq("-")]

# %%
#Dropข้อมูลที่ไม่ได้ใช้ออก
data_features_d= data_features.drop(data_features.index[(data_features['ปริมาณฝน'] == 'T')],axis=0)

# %%
data_features_d
# Out:
#        ความกด  ความชื้น  อุณหภูมิตุ้มแห้ง  อุณหภูมิจุดน้ำค้าง  อุณหภูมิต่ำสุด  \
# 0     1005.47      83.0              27.6                24.2            24.8
# 1     1006.65      92.0              25.6                24.0            23.0
# 2     1007.49      86.0              25.6                22.9            22.1
# 3     1008.28      80.0              25.8                21.9            22.8
# 4     1009.88      86.0              24.3                21.7            23.1
# ...       ...       ...               ...                 ...             ...
# 5203  1008.39      69.0              26.8                18.4            18.0
# 5204  1006.05      61.0              27.8                17.3            19.5
# 5205  1004.86      55.0              26.3                13.0            16.0
# 5206  1005.76      56.0              25.2                13.8            15.3
# 5207  1008.21      58.0              25.6                15.2            16.0
#
# ...

# %%
data_features = data_features.dropna()

# %%
data_features
# Out:
#        ความกด  ความชื้น  อุณหภูมิตุ้มแห้ง  อุณหภูมิจุดน้ำค้าง  อุณหภูมิต่ำสุด  \
# 0     1005.47      83.0              27.6                24.2            24.8
# 1     1006.65      92.0              25.6                24.0            23.0
# 2     1007.49      86.0              25.6                22.9            22.1
# 3     1008.28      80.0              25.8                21.9            22.8
# 4     1009.88      86.0              24.3                21.7            23.1
# ...       ...       ...               ...                 ...             ...
# 5203  1008.39      69.0              26.8                18.4            18.0
# 5204  1006.05      61.0              27.8                17.3            19.5
# 5205  1004.86      55.0              26.3                13.0            16.0
# 5206  1005.76      56.0              25.2                13.8            15.3
# 5207  1008.21      58.0              25.6                15.2            16.0
#
# ...

# %%
data_features_d = data_features_d[data_features_d.eq('T').any(1)==False]
data_features_d.shape
# Out:
# (5061, 8)

# %%
data_features_d['ความเร็วลม'] = data_features_d['ความเร็วลม'].astype(float)
data_features_d['จำนวนเมฆ'] = data_features_d['จำนวนเมฆ'].astype(float)
data_features_d['ปริมาณฝน'] = data_features_d['ปริมาณฝน'].astype(float)
data_features_d['อุณหภูมิต่ำสุด'] = data_features_d['อุณหภูมิต่ำสุด'].astype(float)

# %%
data_features_d.describe()
# Out:
#             ความกด     ความชื้น  อุณหภูมิตุ้มแห้ง  อุณหภูมิจุดน้ำค้าง  \
# count  5061.000000  5061.000000       5061.000000         5061.000000
# mean   1012.731324   324.593705         25.002667           18.420944
# std       3.158633   417.257732          2.720534            3.630472
# min    1002.040000    43.000000         11.800000            1.500000
# 25%    1010.760000    67.000000         23.500000           16.100000
# 50%    1012.610000    76.000000         25.400000           18.500000
# 75%    1014.710000  1008.640000         26.900000           21.200000
# max    1026.100000  1025.710000         31.000000           28.400000
#
#        อุณหภูมิต่ำสุด     จำนวนเมฆ     ปริมาณฝน   ความเร็วลม
# count     5061.000000  5061.000000  5061.000000  5061.000000
# mean        19.933570     3.308832     1.556194     2.284726
# std          3.295887     2.494353     6.816712     1.209540
# min          6.800000     0.000000     0.000000     0.000000
# ...

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=[10,6]

# %%
pd.plotting.scatter_matrix(data_features_d);
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3623 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3634 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3617 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3585 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
from matplotlib import pyplot as plt

# %%
plt.hist(data_features_d['ความกด'])
# Out:
# (array([  29.,  136.,  466., 1269., 1579.,  986.,  450.,  118.,   19.,
#            9.]),
#  array([1002.04 , 1004.446, 1006.852, 1009.258, 1011.664, 1014.07 ,
#         1016.476, 1018.882, 1021.288, 1023.694, 1026.1  ]),
#  <a list of 10 Patch objects>)

# %%
from sklearn import preprocessing

# %%
#define
scaler = scaler =  preprocessing.StandardScaler()
#train
scaler.fit(data_features_d) 
#predict-transform
data_features_d_s = scaler.fit_transform(data_features_d)

# %%
data_features_d_s
# Out:
# array([[-2.29910857, -0.57906075,  0.95480871, ...,  2.28184617,
#         -0.02291572,  0.5914187 ],
#        [-1.92549238, -0.55748922,  0.21958617, ...,  2.68279133,
#          2.36850273, -0.23542385],
#        [-1.65952832, -0.57187024,  0.21958617, ...,  2.68279133,
#          0.21182474,  0.5914187 ],
#        ...,
#        [-2.49224914, -0.64617219,  0.47691406, ..., -1.32666027,
#         -0.22831362, -0.23542385],
#        [-2.20728764, -0.64377535,  0.07254167, ..., -0.52476995,
#         -0.22831362, -1.06226641],
#        [-1.43155912, -0.63898168,  0.21958617, ..., -0.92571511,
#         -0.22831362, -1.06226641]])

# %%
#plot2กราฟข้างๆกัน
plt.subplot(1,2,1)
plt.hist(data_features_d['ความกด'])
plt.subplot(1,2,2)
plt.hist(data_features_d_s[:,0]);

# %%
#plot2กราฟข้างๆกัน
plt.subplot(1,2,1)
plt.hist(data_features_d['ปริมาณฝน'])
plt.subplot(1,2,2)
plt.hist(data_features_d_s[:,0]);

# %% [markdown]
# # Min-Max normalization

# %%
#define
scaler = scaler =  preprocessing.MinMaxScaler()
#train
scaler.fit(data_features_d) 
#predict-transform
data_features_d_norm = scaler.transform(data_features_d)

# %%
plt.subplot(1,3,1)
plt.hist(data_features_d['ความกด'])
plt.subplot(1,3,2)
plt.hist(data_features_d_s[:,0]); # รู้ mean แต่ละคอลัมน์ 
plt.subplot(1,3,3)
plt.hist(data_features_d_norm[:,0]); # ค่าจะอยู่ระหว่าง 0 - 1 แต่ไม่รู้ว่า mean เท่าไหร่

# %% [markdown]
# #Discretization

# %%
home_data =pd.read_csv('/content/drive/MyDrive/bsc_DPDM_data/15กัลยรัตน์_บุญกอง.csv')

# %%
home_data.head()
# Out:
#    post_id  number_of_rai  number_of_ngan  number_of_va  number_of_story  \
# 0     25.0            0.0             0.0          63.8              1.0
# 1     33.0            0.0             0.0          61.1              1.0
# 2    495.0            NaN             3.0          12.8              NaN
# 3    564.0            NaN             NaN          85.0              NaN
# 4    566.0            NaN             NaN          65.0              NaN
#
#    number_of_bedroom  number_of_bathroom  direction  furniture  usable_area  \
# 0                3.0                 2.0        0.0        0.0        135.0
# 1                2.0                 2.0        0.0        0.0        112.0
# 2                0.0                 NaN        0.0        0.0          0.0
# 3                0.0                 NaN        0.0        0.0          0.0
# 4                0.0                 NaN        0.0        0.0          0.0
#
# ...

# %%
#(ลบ record) Drop ค่าmissingที่อยู่ใน cell price ออก

# %%
home_data = home_data.dropna(subset=['sell_price'])

# %%
home_data.head()
# Out:
#    post_id  number_of_rai  number_of_ngan  number_of_va  number_of_story  \
# 0     25.0            0.0             0.0          63.8              1.0
# 1     33.0            0.0             0.0          61.1              1.0
# 2    495.0            NaN             3.0          12.8              NaN
# 3    564.0            NaN             NaN          85.0              NaN
# 4    566.0            NaN             NaN          65.0              NaN
#
#    number_of_bedroom  number_of_bathroom  direction  furniture  usable_area  \
# 0                3.0                 2.0        0.0        0.0        135.0
# 1                2.0                 2.0        0.0        0.0        112.0
# 2                0.0                 NaN        0.0        0.0          0.0
# 3                0.0                 NaN        0.0        0.0          0.0
# 4                0.0                 NaN        0.0        0.0          0.0
#
# ...

# %%
plt.hist(home_data['sell_price']);

# %% [markdown]
# ### แปลงค่า sell_price
#   แบ่งบ้านเป็น 3 grade
# - ราคาต่ำกว่า 5m ให้เป็น 1
# - ราคาระหว่าง 5m -10m ให้เป็น 2
# - ราคา 10m ขึ้นไปให้เป็น 3

# %%
hds= home_data[['sell_price']]

# %%
hds['Grade']='3'
hds['Grade'][(hds['sell_price'] > 10000000)]='3'
hds['Grade'][(hds['sell_price'] <= 10000000) | (hds['sell_price']>=5000000)]='2'
hds['Grade'][(hds['sell_price'] < 5000000)]='1'
# Out:
# <ipython-input-113-f5811e6b44ee>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hds['Grade']='3'
# <ipython-input-113-f5811e6b44ee>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hds['Grade'][(hds['sell_price'] > 10000000)]='3'
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:8870: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
hds
# Out:
#     sell_price Grade
# 0    2700000.0     1
# 1    2600000.0     1
# 2    5900000.0     2
# 3    4400000.0     1
# 4    2750000.0     1
# ..         ...   ...
# 95   5500000.0     2
# 96   7911000.0     2
# 97   2990000.0     1
# 98   4000000.0     1
# 99   1375000.0     1
#
# [100 rows x 2 columns]

# %% [markdown]
# ###One-hot-Encoder

# %%
home_data-dummies = pd.get_dummies(home_data,columns= ['zone','furniture','renovate','direction',])
# Out:
#   File "<ipython-input-116-b9b2ecad7098>", line 1
#     home_data-dummies = pd.get_dummies(home_data,columns= ['zone','furniture','renovate','direction',])
#     ^
# SyntaxError: cannot assign to operator
